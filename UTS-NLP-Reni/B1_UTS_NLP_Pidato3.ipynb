# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
# !pip install PySastrawi
# Out:
# Requirement already satisfied: PySastrawi in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (1.2.0)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (1.0.1)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
f = open('D:/STT_Cipasung/Kuliah Semester 7/Pemrosesan Teks dan Suara Alami/UTS/pidato3.txt', 'r')
isi_berita = f.read()
print(isi_berita)
# Out:
# presiden joko widodo  dalam pidatonya menyampaikan bahwa  patut bersyukur indonesia termasuk negara  mampu menghadapi krisis global  indonesia termasuk negara  berhasil mengendalikan pandemi covid-19 termasuk lima besar negara dengan vaksinasi terbanyak  dunia yaitu 432 juta dosis vaksin  telah  suntikan inflasi juga berhasil kendalikan  kisaran 49% angka  jauh  bawah rata-rata inflasi asia  berada  ser 7%  jauh  bawah inflasi negara-negara maju  berada  ser 9% bahkan sampai pertengahan tahun 2022  apbn juga surplus 106 triliun rupiah katanya ekonomi berhasil tumbuh positif  angka 544% pada kuartal kedua tahun 2022  neraca perdagangan juga surplus selama 27 bulan berturut-turut   semester i tahun 2022  surplusnya ser 364 triliun rupiah capaian tersebut patut  syukuri fundamental ekonomi indonesia tetap sangat baik  tengah ekonomi dunia  seg bergolak  satu sisi  memang harus tetap waspada  harus tetap hati-hati namun  sisi lain agenda-agenda bangsa harus terus  lanjutkan untuk meraih indonesia maju tegasnya
# oleh karena itu bu pekerti  luhur ideologi pancasila bhinneka tunggal ika  patriotisme merupakan pilar utama seni  trasi lokal dengan semangat kebangsaan harus terus gairahkan saya mengajak seluruh komponen bangsa untuk bersatu padu untuk mendukung agenda besar bagi pencapaian indonesia maju dengan komitmen dengan kerja keras dengan inovasi  kreatifitas semoga allah swt tuhan  maha kuasa senantiasa mempermudah upaya  dalam meraih indonesia maju   cita-citakan indonesia pulih lebih cepat bangkit lebih kuat rgahayu republik indonesia rgahayu negeri pancasila merdeka tandasnya

# %%
word_tokens = word_tokenize(isi_berita)
print(word_tokens)
# Out:
# ['presiden', 'joko', 'widodo', 'dalam', 'pidatonya', 'menyampaikan', 'bahwa', 'patut', 'bersyukur', 'indonesia', 'termasuk', 'negara', 'mampu', 'menghadapi', 'krisis', 'global', 'indonesia', 'termasuk', 'negara', 'berhasil', 'mengendalikan', 'pandemi', 'covid-19', 'termasuk', 'lima', 'besar', 'negara', 'dengan', 'vaksinasi', 'terbanyak', 'dunia', 'yaitu', '432', 'juta', 'dosis', 'vaksin', 'telah', 'suntikan', 'inflasi', 'juga', 'berhasil', 'kendalikan', 'kisaran', '49', '%', 'angka', 'jauh', 'bawah', 'rata-rata', 'inflasi', 'asia', 'berada', 'ser', '7', '%', 'jauh', 'bawah', 'inflasi', 'negara-negara', 'maju', 'berada', 'ser', '9', '%', 'bahkan', 'sampai', 'pertengahan', 'tahun', '2022', 'apbn', 'juga', 'surplus', '106', 'triliun', 'rupiah', 'katanya', 'ekonomi', 'berhasil', 'tumbuh', 'positif', 'angka', '544', '%', 'pada', 'kuartal', 'kedua', 'tahun', '2022', 'neraca', 'perdagangan', 'juga', 'surplus', 'selama', '27', 'bulan', 'berturut-turut', 'semester', 'i', 'tahun', '2022', 'surplusnya', 'ser', '364', 'triliun', 'rupiah', 'capaian', 'tersebut', 'patut', 'syukuri', 'fundamental', 'ekonomi', 'indonesia', 'tetap', 'sangat', 'baik', 'tengah', 'ekonomi', 'dunia', 'seg', 'bergolak', 'satu', 'sisi', 'memang', 'harus', 'tetap', 'waspada', 'harus', 'tetap', 'hati-hati', 'namun', 'sisi', 'lain', 'agenda-agenda', 'bangsa', 'harus', 'terus', 'lanjutkan', 'untuk', 'meraih', 'indonesia', 'maju', 'tegasnya', 'oleh', 'karena', 'itu', 'bu', 'pekerti', 'luhur', 'ideologi', 'pancasila', 'bhinneka', 'tunggal', 'ika', 'patriotisme', 'merupakan', 'pilar', 'utama', 'seni', 'trasi', 'lokal', 'dengan', 'semangat', 'kebangsaan', 'harus', 'terus', 'gairahkan', 'saya', 'mengajak', 'seluruh', 'komponen', 'bangsa', 'untuk', 'bersatu', 'padu', 'untuk', 'mendukung', 'agenda', 'besar', 'bagi', 'pencapaian', 'indonesia', 'maju', 'dengan', 'komitmen', 'dengan', 'kerja', 'keras', 'dengan', 'inovasi', 'kreatifitas', 'semoga', 'allah', 'swt', 'tuhan', 'maha', 'kuasa', 'senantiasa', 'mempermudah', 'upaya', 'dalam', 'meraih', 'indonesia', 'maju', 'cita-citakan', 'indonesia', 'pulih', 'lebih', 'cepat', 'bangkit', 'lebih', 'kuat', 'rgahayu', 'republik', 'indonesia', 'rgahayu', 'negeri', 'pancasila', 'merdeka', 'tandasnya']

# %%
stop_words = set(stopwords.words('indonesian'))
word_tokens_no_stopwords = [w for w in word_tokens if not w in stop_words]
print(word_tokens_no_stopwords)
# Out:
# ['presiden', 'joko', 'widodo', 'pidatonya', 'patut', 'bersyukur', 'indonesia', 'negara', 'menghadapi', 'krisis', 'global', 'indonesia', 'negara', 'berhasil', 'mengendalikan', 'pandemi', 'covid-19', 'negara', 'vaksinasi', 'dunia', '432', 'juta', 'dosis', 'vaksin', 'suntikan', 'inflasi', 'berhasil', 'kendalikan', 'kisaran', '49', '%', 'angka', 'rata-rata', 'inflasi', 'asia', 'ser', '7', '%', 'inflasi', 'negara-negara', 'maju', 'ser', '9', '%', 'pertengahan', '2022', 'apbn', 'surplus', '106', 'triliun', 'rupiah', 'ekonomi', 'berhasil', 'tumbuh', 'positif', 'angka', '544', '%', 'kuartal', '2022', 'neraca', 'perdagangan', 'surplus', '27', 'semester', 'i', '2022', 'surplusnya', 'ser', '364', 'triliun', 'rupiah', 'capaian', 'patut', 'syukuri', 'fundamental', 'ekonomi', 'indonesia', 'ekonomi', 'dunia', 'seg', 'bergolak', 'sisi', 'waspada', 'hati-hati', 'sisi', 'agenda-agenda', 'bangsa', 'lanjutkan', 'meraih', 'indonesia', 'maju', 'bu', 'pekerti', 'luhur', 'ideologi', 'pancasila', 'bhinneka', 'tunggal', 'ika', 'patriotisme', 'pilar', 'utama', 'seni', 'trasi', 'lokal', 'semangat', 'kebangsaan', 'gairahkan', 'mengajak', 'komponen', 'bangsa', 'bersatu', 'padu', 'mendukung', 'agenda', 'pencapaian', 'indonesia', 'maju', 'komitmen', 'kerja', 'keras', 'inovasi', 'kreatifitas', 'semoga', 'allah', 'swt', 'tuhan', 'maha', 'kuasa', 'senantiasa', 'mempermudah', 'upaya', 'meraih', 'indonesia', 'maju', 'cita-citakan', 'indonesia', 'pulih', 'cepat', 'bangkit', 'kuat', 'rgahayu', 'republik', 'indonesia', 'rgahayu', 'negeri', 'pancasila', 'merdeka']

# %%
freq_kata_1 = nltk.FreqDist(word_tokens)
freq_kata_2 = nltk.FreqDist(word_tokens_no_stopwords)
print(freq_kata_1.most_common(20))
print()
print(freq_kata_2.most_common(20))
# Out:
# [('indonesia', 8), ('dengan', 5), ('%', 4), ('maju', 4), ('harus', 4), ('termasuk', 3), ('negara', 3), ('berhasil', 3), ('inflasi', 3), ('juga', 3), ('ser', 3), ('tahun', 3), ('2022', 3), ('ekonomi', 3), ('tetap', 3), ('untuk', 3), ('dalam', 2), ('patut', 2), ('besar', 2), ('dunia', 2)]
#
# [('indonesia', 8), ('%', 4), ('maju', 4), ('negara', 3), ('berhasil', 3), ('inflasi', 3), ('ser', 3), ('2022', 3), ('ekonomi', 3), ('patut', 2), ('dunia', 2), ('angka', 2), ('surplus', 2), ('triliun', 2), ('rupiah', 2), ('sisi', 2), ('bangsa', 2), ('meraih', 2), ('pancasila', 2), ('rgahayu', 2)]

# %%
import matplotlib.pyplot as plt

# %%
freq_kata_1.plot(20)
freq_kata_2.plot(20)
plt.show()

# %%
#Import datavis libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline
sns.set()

# Create freq dist and plot
freqdist1 = nltk.FreqDist(word_tokens_no_stopwords)
freqdist1.plot(25)
plt.show()
