# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
# !pip install PySastrawi
# Out:
# Requirement already satisfied: PySastrawi in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (1.2.0)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (1.0.1)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
f = open('D:/STT_Cipasung/Kuliah Semester 7/Pemrosesan Teks dan Suara Alami/UTS/pidato.txt', 'r')
isi_berita = f.read()
print(isi_berita)
# Out:
# sebanyak 215 negara tanpa terkecuali seg menghadapi masa sulit terpa pandemi covid-19  catatan who sampai  tanggal 13 agustus kemarin terdapat lebih  20 juta kasus  dunia  jumlah kematian  dunia sebanyak 737 ribu jiwa
# semua negara negara miskin negara berkembang termasuk negara maju semuanya seg mengalami kemunduran karena terpapar covid-19
# krisis perekonomian dunia juga terparah  sejarah  kuartal pertama 2020 pertumbuhan ekonomi negara  masih plus 297% tapi  kuartal kedua  minus 532% ekonomi negara-negara maju bahkan minus belasan persen sampai minus 17% kemunduran banyak negara besar  bisa menja peluang momentum bagi   mengejar ketertinggalan
# ibarat komputer perekonomian semua negara saat  seg macet seg hang semua negara  menjalani proses mati komputer sesaat  melakukan re -start  melakukan re-booting semua negara mempunyai kesempatan men-setting ulang semua sistemnya
# saya menyambut hangat seruan moral penuh kearifan  para ulama para pemuka agama tokoh-tokoh budaya agar menjakan momentum musibah pandemi  sebagai sebuah kebangn baru  melakukan sebuah lompatan besar
# lah saatnya  membenahi ri secara fundamental melakukan transformasi besar menjalankan strategi besar strategi besar  big ekonomi hukum pemerintahan sosial kebudayaan termasuk kesehatan penkan
# saatnya  bajak momentum krisis  melakukan lompatan-lompatan besar pada usia ke-75 tahun   telah menja negara upper middleincome country 25 tahun lagi pada usia seabad republik indonesia   mencapai kemajuan  besar menjakan indonesia negara maju
# sepanjang tahun 2019 hingga juni 2020 ky telah menangani 1584 laporan masyarakatmerekomendasikan 225 penjatuhan sanksi
# kecepatan kecermatan mahkamah konstitusi juga sangat patut apresiasi mk juga terus memperbaiki tata kelolameningkatkan pemanfaatan layanan elektronik  melayani masyarakat  mencari kealanmk telah berhasil mempercepat jangka waktu penyelesaian perkara pengujian ung-ung  waktu penyelesaian 101 hari kerja per perkara  2017 menja rata-rata 59 hari kerja per perkara sepanjang tahun 2019 hingga awal tahun 2020 mk telah menyelesaikan 122 perkara pengujian ung-ung
# pada saat  sama perluasan kerja sama   maupun  luar negeri terus tingkatkan mk aktif mengsiasimengkoornasi berbagai kegiatan  tingkat regional maupun global agar sistem hukum  jakan rujukan bagi negara-negara demokrasi  berbagai penjuru dunia
# saudara-saudara se-bangsase-tanah air masih banyak langkah- langkah besar    lakukan masih tersea waktu 25 tahun lagi bagi   menyiapkan seabad indonesia merdeka membangun indonesia   cita-citakan
# target  saat bukan hanya lepas  pandemi bukan hanya keluar  krisis langkah  adalah melakukan lompatan besar memanfaatkan momentum krisis  saat  seg terja
# krisis memberikan momentum bagi   mengejar ketertinggalan melakukan transformasi besar melaksanakan strategi besar mari pecahkan masalah fundamental hadapi  lakukan lompatan besar  kemajuan  signifikan bajak momentum krisis serentakserempak memanfaatkan momentum menjakan indonesia setara negara-negara maju menjakan indonesia maju   cita-citakan
# rgahayu republik indonesia!
# rgahayu negeri pancasila!
# merdeka!
# terima kasih wassalamu'alaikum warahmatullahi wabarakatuh om shanti shanti shanti om namo buddhaya
# jakarta 14 agustus 2020
# presiden republik indonesia
# joko widodo

# %%
word_tokens = word_tokenize(isi_berita)
print(word_tokens)
# Out:
# ['sebanyak', '215', 'negara', 'tanpa', 'terkecuali', 'seg', 'menghadapi', 'masa', 'sulit', 'terpa', 'pandemi', 'covid-19', 'catatan', 'who', 'sampai', 'tanggal', '13', 'agustus', 'kemarin', 'terdapat', 'lebih', '20', 'juta', 'kasus', 'dunia', 'jumlah', 'kematian', 'dunia', 'sebanyak', '737', 'ribu', 'jiwa', 'semua', 'negara', 'negara', 'miskin', 'negara', 'berkembang', 'termasuk', 'negara', 'maju', 'semuanya', 'seg', 'mengalami', 'kemunduran', 'karena', 'terpapar', 'covid-19', 'krisis', 'perekonomian', 'dunia', 'juga', 'terparah', 'sejarah', 'kuartal', 'pertama', '2020', 'pertumbuhan', 'ekonomi', 'negara', 'masih', 'plus', '297', '%', 'tapi', 'kuartal', 'kedua', 'minus', '532', '%', 'ekonomi', 'negara-negara', 'maju', 'bahkan', 'minus', 'belasan', 'persen', 'sampai', 'minus', '17', '%', 'kemunduran', 'banyak', 'negara', 'besar', 'bisa', 'menja', 'peluang', 'momentum', 'bagi', 'mengejar', 'ketertinggalan', 'ibarat', 'komputer', 'perekonomian', 'semua', 'negara', 'saat', 'seg', 'macet', 'seg', 'hang', 'semua', 'negara', 'menjalani', 'proses', 'mati', 'komputer', 'sesaat', 'melakukan', 're', '-start', 'melakukan', 're-booting', 'semua', 'negara', 'mempunyai', 'kesempatan', 'men-setting', 'ulang', 'semua', 'sistemnya', 'saya', 'menyambut', 'hangat', 'seruan', 'moral', 'penuh', 'kearifan', 'para', 'ulama', 'para', 'pemuka', 'agama', 'tokoh-tokoh', 'budaya', 'agar', 'menjakan', 'momentum', 'musibah', 'pandemi', 'sebagai', 'sebuah', 'kebangn', 'baru', 'melakukan', 'sebuah', 'lompatan', 'besar', 'lah', 'saatnya', 'membenahi', 'ri', 'secara', 'fundamental', 'melakukan', 'transformasi', 'besar', 'menjalankan', 'strategi', 'besar', 'strategi', 'besar', 'big', 'ekonomi', 'hukum', 'pemerintahan', 'sosial', 'kebudayaan', 'termasuk', 'kesehatan', 'penkan', 'saatnya', 'bajak', 'momentum', 'krisis', 'melakukan', 'lompatan-lompatan', 'besar', 'pada', 'usia', 'ke-75', 'tahun', 'telah', 'menja', 'negara', 'upper', 'middleincome', 'country', '25', 'tahun', 'lagi', 'pada', 'usia', 'seabad', 'republik', 'indonesia', 'mencapai', 'kemajuan', 'besar', 'menjakan', 'indonesia', 'negara', 'maju', 'saudara-saudara', 'se-bangsase-tanah', 'air', 'melakukan', 'reformasi', 'fundamental', 'cara', 'bekerja', 'kesiap-siagaankecepatan', 'uji', 'mengevakuasi', 'warga', 'negara', 'indonesia', 'wilayah', 'pandemi', 'tiongkok', 'menyiapkan', 'rumah', 'sakit', 'rumah', 'isolasi', 'obat-obatan', 'alat', 'kesehatanmensiplinkan', 'protokol', 'kesehatan', 'semuanya', 'lakukan', 'secara', 'cepat', 'waktu', 'sangat', 'singkat', 'ketika', 'krisis', 'kesehatan', 'tersebut', 'berdampak', 'pada', 'perekonomian', 'nasional', 'juga', 'cepat', 'bergerak', ':', 'memberikan', 'bantuan', 'sosial', 'bagi', 'masyarakat', 'melalui', 'bantuan', 'sembako', 'bansos', 'tunai', 'subsiskon', 'tarif', 'listrik', 'blt', 'desasubsi', 'gaji', 'membantu', 'umkm', 'memperoleh', 'restrukturisasi', 'kret', 'memperoleh', 'banpres', 'produktif', 'berupa', 'bantuan', 'modal', 'darurat', 'membantu', 'pembelian', 'produk-produk', 'mereka', 'membantu', 'tenaga', 'kerja', 'menja', 'korban', 'phk', 'antara', 'lain', 'melalui', 'bantuan', 'sosialprogram', 'prakerja', 'sesuatu', 'tidak', 'mudah', 'itu', 'semua', 'pemerintah', 'cepat', 'melakukan', 'perubahan', 'rumusan', 'program', 'menyesuaikan', 'program', 'kerja', 'situasi', 'terk', 'melakukan', 'realokasi', 'anggaran', 'waktu', 'singkat', 'menerbitkan', 'perppu', 'no1', 'tahun', '2020', 'kemuan', 'setujui', 'oleh', 'dpr', 'menja', 'uu', 'no2', 'tahun', '2020', 'bersinergi', 'bi', 'ojk', 'lps', 'memulihkan', 'perekonomian', 'krisis', 'telah', 'memaksa', 'menggeser', 'channel', 'cara', 'kerja', 'cara-cara', 'normal', 'menja', 'cara-cara', 'ekstra-normal', 'cara-cara', 'biasa', 'menja', 'cara-cara', 'luar', 'biasa', 'prosedur', 'panjang', 'berbelit', 'menja', 'smart', 'short', 'cut', 'orientasi', 'prosedur', 'menja', 'orientasi', 'hasil', 'pola', 'pikir', 'etos', 'kerja', 'berubah', 'fleksibilitas', 'kecepatan', 'ketepatan', 'sangat', 'butuhkan', 'efisiensi',  ...

# %%
stop_words = set(stopwords.words('indonesian'))
word_tokens_no_stopwords = [w for w in word_tokens if not w in stop_words]
print(word_tokens_no_stopwords)
# Out:
# ['215', 'negara', 'terkecuali', 'seg', 'menghadapi', 'sulit', 'terpa', 'pandemi', 'covid-19', 'catatan', 'who', 'tanggal', '13', 'agustus', 'kemarin', '20', 'juta', 'dunia', 'kematian', 'dunia', '737', 'ribu', 'jiwa', 'negara', 'negara', 'miskin', 'negara', 'berkembang', 'negara', 'maju', 'seg', 'mengalami', 'kemunduran', 'terpapar', 'covid-19', 'krisis', 'perekonomian', 'dunia', 'terparah', 'sejarah', 'kuartal', '2020', 'pertumbuhan', 'ekonomi', 'negara', 'plus', '297', '%', 'kuartal', 'minus', '532', '%', 'ekonomi', 'negara-negara', 'maju', 'minus', 'belasan', 'persen', 'minus', '17', '%', 'kemunduran', 'negara', 'menja', 'peluang', 'momentum', 'mengejar', 'ketertinggalan', 'komputer', 'perekonomian', 'negara', 'seg', 'macet', 'seg', 'hang', 'negara', 'menjalani', 'proses', 'mati', 'komputer', 're', '-start', 're-booting', 'negara', 'kesempatan', 'men-setting', 'ulang', 'sistemnya', 'menyambut', 'hangat', 'seruan', 'moral', 'penuh', 'kearifan', 'ulama', 'pemuka', 'agama', 'tokoh-tokoh', 'budaya', 'menjakan', 'momentum', 'musibah', 'pandemi', 'kebangn', 'lompatan', 'membenahi', 'ri', 'fundamental', 'transformasi', 'menjalankan', 'strategi', 'strategi', 'big', 'ekonomi', 'hukum', 'pemerintahan', 'sosial', 'kebudayaan', 'kesehatan', 'penkan', 'bajak', 'momentum', 'krisis', 'lompatan-lompatan', 'usia', 'ke-75', 'menja', 'negara', 'upper', 'middleincome', 'country', '25', 'usia', 'seabad', 'republik', 'indonesia', 'mencapai', 'kemajuan', 'menjakan', 'indonesia', 'negara', 'maju', 'saudara-saudara', 'se-bangsase-tanah', 'air', 'reformasi', 'fundamental', 'kesiap-siagaankecepatan', 'uji', 'mengevakuasi', 'warga', 'negara', 'indonesia', 'wilayah', 'pandemi', 'tiongkok', 'rumah', 'sakit', 'rumah', 'isolasi', 'obat-obatan', 'alat', 'kesehatanmensiplinkan', 'protokol', 'kesehatan', 'lakukan', 'cepat', 'singkat', 'krisis', 'kesehatan', 'berdampak', 'perekonomian', 'nasional', 'cepat', 'bergerak', ':', 'bantuan', 'sosial', 'masyarakat', 'bantuan', 'sembako', 'bansos', 'tunai', 'subsiskon', 'tarif', 'listrik', 'blt', 'desasubsi', 'gaji', 'membantu', 'umkm', 'memperoleh', 'restrukturisasi', 'kret', 'memperoleh', 'banpres', 'produktif', 'bantuan', 'modal', 'darurat', 'membantu', 'pembelian', 'produk-produk', 'membantu', 'tenaga', 'kerja', 'menja', 'korban', 'phk', 'bantuan', 'sosialprogram', 'prakerja', 'mudah', 'pemerintah', 'cepat', 'perubahan', 'rumusan', 'program', 'menyesuaikan', 'program', 'kerja', 'situasi', 'terk', 'realokasi', 'anggaran', 'singkat', 'menerbitkan', 'perppu', 'no1', '2020', 'kemuan', 'setujui', 'dpr', 'menja', 'uu', 'no2', '2020', 'bersinergi', 'bi', 'ojk', 'lps', 'memulihkan', 'perekonomian', 'krisis', 'memaksa', 'menggeser', 'channel', 'kerja', 'cara-cara', 'normal', 'menja', 'cara-cara', 'ekstra-normal', 'cara-cara', 'menja', 'cara-cara', 'prosedur', 'berbelit', 'menja', 'smart', 'short', 'cut', 'orientasi', 'prosedur', 'menja', 'orientasi', 'hasil', 'pola', 'pikir', 'etos', 'kerja', 'berubah', 'fleksibilitas', 'kecepatan', 'ketepatan', 'butuhkan', 'efisiensi', 'kolaborasi', 'penggunaan', 'teknologi', 'prioritaskan', 'kesiplinan', 'nasionalproduktivitas', 'nasional', 'tingkatkan', 'sia-siakan', 'pelajaran', 'krisis', 'biarkan', 'krisis', 'membuahkan', 'kemunduran', 'momentum', 'krisis', 'bajak', 'lompatan', 'kemajuan', 'saudara-saudara', 'se-bangsa', 'se-tanah', 'air', 'perjuangan', 'menghambat', 'penyebaran', 'covid-19', 'mengobati', 'sakit', 'mencegah', 'kematian', 'lakukan', 'nama', 'rakyat', 'bangsa', 'negara', 'terima', 'kasih', 'penghargaan', 'setinggi-tingginya', 'dokter', 'perawat', 'petugas', 'rumah', 'sakit', 'laboratorium', 'klk-klk', 'kesehatan', 'rumah', 'isolasi', 'tokoh', 'masyarakat', 'relawan', 'awak', 'mea', 'aparat', 'tni', 'polri', 'asn', 'pusat', 'daerah', 'peristiwa', 'pandemi', 'reformasi', 'fundamental', 'sektor', 'kesehatan', 'percepat', 'orientasi', 'pencegahan', 'penyakit', 'pola', 'hidup', 'sehat', 'utamakan', 'penguatan', 'kapasitas', 'sdm', 'pengembangan', 'rumah', 'sakitbalai', 'kese ...

# %%
freq_kata_1 = nltk.FreqDist(word_tokens)
freq_kata_2 = nltk.FreqDist(word_tokens_no_stopwords)
print(freq_kata_1.most_common(20))
print()
print(freq_kata_2.most_common(20))
# Out:
# [('negara', 17), ('besar', 17), ('menja', 17), ('indonesia', 16), ('juga', 15), ('kerja', 14), ('semua', 13), ('krisis', 13), ('melakukan', 13), ('tahun', 13), ('tidak', 12), ('serta', 11), ('seg', 10), ('bagi', 10), ('kesehatan', 10), ('2020', 9), ('bisa', 9), ('momentum', 9), ('telah', 9), ('lakukan', 9)]
#
# [('negara', 17), ('menja', 17), ('indonesia', 16), ('kerja', 14), ('krisis', 13), ('seg', 10), ('kesehatan', 10), ('2020', 9), ('momentum', 9), ('lakukan', 9), ('nasional', 9), ('pandemi', 8), ('bangsa', 8), ('ekonomi', 7), ('hukum', 7), ('kemajuan', 7), ('saudara-saudara', 7), ('air', 7), ('industri', 7), ('perekonomian', 6)]

# %%
import matplotlib.pyplot as plt

# %%
freq_kata_1.plot(20)
freq_kata_2.plot(20)
plt.show()

# %%
#Import datavis libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline
sns.set()

# Create freq dist and plot
freqdist1 = nltk.FreqDist(word_tokens_no_stopwords)
freqdist1.plot(25)
plt.show()
