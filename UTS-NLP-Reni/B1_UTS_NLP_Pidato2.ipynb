# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
# !pip install PySastrawi
# Out:
# Requirement already satisfied: PySastrawi in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (1.2.0)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (1.0.1)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
f = open('D:/STT_Cipasung/Kuliah Semester 7/Pemrosesan Teks dan Suara Alami/UTS/Pidato2.txt', 'r')
isi_berita = f.read()
print(isi_berita)
# Out:
# oleh karena    memperkuat fondasi  mengumpulkan energi  melakukan lompatan kemajuan   berani melakukan terobosan  melompat jauh ke depan   berani membuat kebijakan  hasilnya   nikmati saat ini tapi membuat langkah  ke depan menjadi lebih cepat   boleh terjebak dalam pragmatisme jangka pendek  justru membuat jalan  melambat di masa depan   boleh terjebak pada status sebagai negara berpenghasilan menengah   boleh terkena middle income trap tapi   berhasil menjadi negara maju menjadi indonesia  maju oleh karena  apa   lakukan kemarin  saat ini bukanlah semata-mata  memecahkan masalah masa kini atau masalah satu-dua tahun ke depan tetapi semua  juga menjadi bagian dari lompatan kemajuan indonesia  menjawab masalah-masalah  di masa depan keberhasilan timnas sepakbola indonesia u-16 menjuarai turnamen asean football federation pada 11 agustus 2018 adalah salah satu contohnya tim  masih berusia 16 tahun ke bawah ini adalah masa depan sepakbola indonesia mereka adalah masa depan indonesia benih-benih harapan  kejayaan bangsa indonesia dari hari ke hari semakin bersemai putra-putri indonesia  mengibarkan bendera merah putih di pentas dunia semakin banyak prestasi gemilang  membanggakan  semua diraih oleh putraputri indonesia dalam berbagai kompetisi tingkat dunia dalam kompetisi big sains  teknologi lomba hafal al-quran festival seni  budaya kejuaraan olah raga serta berbagai kompetisi lainnya  berhasil menggaet posisi terhormat prestasi  diraih anak-anak bangsa tersebut  didukung oleh ekosistem  kondusif sehingga bisa lebih berkontribusi  indonesia maju ekosistem demokrasi ideologi pancasila  kokoh bhinneka tunggal ika  semangat gotong royong  ditopang dengan tata kelola pemerintahan  baik upaya  membebaskan indonesia dari jeratan korupsi  mengkhianati kepercayaan rakyat menggerogoti anggaran negara  merusak sendi-sendi perekonomian bangsa  terus dilakukan korupsi adalah kejahatan luar biasa   dilawan dengan cara-cara  luar biasa pemerintah akan terus mendukung upaya kpk  memberantas korupsi pemerintah juga memberikan prioritas  tinggi pada upaya pencegahan sebagaimana halnya dengan upaya penindakan   pemerintah telah mengeluarkan strategi nasional pencegahan korupsi melalui peraturan presiden nomor 54 tahun 2018 sebagai arah kebijakan nasional  memuat fokus  sasaran pencegahan korupsi selain  pemerintah juga meneruskan inisiatif saber pungli satuan tugas sapu bersih pungutan liar  sampai semester i tahun 2018 telah melaksanakan 2911 kegiatan operasi tangkap tangan  juga  memberikan perhatian  kuat pada upaya penghormatan perlindungan pemenuhan  penegakan hak asasi manusia   menjadi semangat pemerintah dalam mengeluarkan peraturan presiden nomor 33 tahun 2018 tentang perubahan atas peraturan presiden nomor 75 tahun 2015 tentang rencana aksi nasional hak asasi manusia (ranham) tahun 2015-2019 pemerintah berupaya mempercepat penyelesaian kasus-kasus ham masa lalu serta meningkatkan perlindungan ham agar kejadian  sama  terulang lagi di kemudian hari dalam melakukan berbagai lompatan kemajuan  membutuhkan keberanian   memiliki ketegasan  mengambil keputusan  terbaik bagi kepentingan rakyat indonesia termasuk ketegasan  melindungi hutan  lahan  upaya  telah membuahkan hasil area kebakaran hutan  lahan menurun signifikan dibandingkan tahun-tahun sebelumnya namun ketegasan tersebut  akan bisa maksimal tanpa dukungan  partisipasi masyarakat saya menyampaikan terima kasih  penghargaan kepada aparat tni polri pemerintah daerah  seluruh warga masyarakat  dengan penuh dedikasi mencegah  melawan ancaman kebakaran hutan ketegasan juga dibutuhkan dalam pemberantasan narkoba  merusak masa depan bangsa upaya ini membutuhkan kerja bersama  semua guna menyelamatkan nyawa belasan ribu putra-putri   setiap tahunnya menjadi korban kejahatan narkoba ketegasan juga  dilakukan dalam menjaga kekayaan alam   berdaulat atas sumber daya alam  kedaulatan maritim mulai dari laut teluk sampai dengan samudra terus  jaga   main-main dengan aksi pencurian ikan  dulu s ...

# %%
word_tokens = word_tokenize(isi_berita)
print(word_tokens)
# Out:
# ['oleh', 'karena', 'memperkuat', 'fondasi', 'mengumpulkan', 'energi', 'melakukan', 'lompatan', 'kemajuan', 'berani', 'melakukan', 'terobosan', 'melompat', 'jauh', 'ke', 'depan', 'berani', 'membuat', 'kebijakan', 'hasilnya', 'nikmati', 'saat', 'ini', 'tapi', 'membuat', 'langkah', 'ke', 'depan', 'menjadi', 'lebih', 'cepat', 'boleh', 'terjebak', 'dalam', 'pragmatisme', 'jangka', 'pendek', 'justru', 'membuat', 'jalan', 'melambat', 'di', 'masa', 'depan', 'boleh', 'terjebak', 'pada', 'status', 'sebagai', 'negara', 'berpenghasilan', 'menengah', 'boleh', 'terkena', 'middle', 'income', 'trap', 'tapi', 'berhasil', 'menjadi', 'negara', 'maju', 'menjadi', 'indonesia', 'maju', 'oleh', 'karena', 'apa', 'lakukan', 'kemarin', 'saat', 'ini', 'bukanlah', 'semata-mata', 'memecahkan', 'masalah', 'masa', 'kini', 'atau', 'masalah', 'satu-dua', 'tahun', 'ke', 'depan', 'tetapi', 'semua', 'juga', 'menjadi', 'bagian', 'dari', 'lompatan', 'kemajuan', 'indonesia', 'menjawab', 'masalah-masalah', 'di', 'masa', 'depan', 'keberhasilan', 'timnas', 'sepakbola', 'indonesia', 'u-16', 'menjuarai', 'turnamen', 'asean', 'football', 'federation', 'pada', '11', 'agustus', '2018', 'adalah', 'salah', 'satu', 'contohnya', 'tim', 'masih', 'berusia', '16', 'tahun', 'ke', 'bawah', 'ini', 'adalah', 'masa', 'depan', 'sepakbola', 'indonesia', 'mereka', 'adalah', 'masa', 'depan', 'indonesia', 'benih-benih', 'harapan', 'kejayaan', 'bangsa', 'indonesia', 'dari', 'hari', 'ke', 'hari', 'semakin', 'bersemai', 'putra-putri', 'indonesia', 'mengibarkan', 'bendera', 'merah', 'putih', 'di', 'pentas', 'dunia', 'semakin', 'banyak', 'prestasi', 'gemilang', 'membanggakan', 'semua', 'diraih', 'oleh', 'putraputri', 'indonesia', 'dalam', 'berbagai', 'kompetisi', 'tingkat', 'dunia', 'dalam', 'kompetisi', 'big', 'sains', 'teknologi', 'lomba', 'hafal', 'al-quran', 'festival', 'seni', 'budaya', 'kejuaraan', 'olah', 'raga', 'serta', 'berbagai', 'kompetisi', 'lainnya', 'berhasil', 'menggaet', 'posisi', 'terhormat', 'prestasi', 'diraih', 'anak-anak', 'bangsa', 'tersebut', 'didukung', 'oleh', 'ekosistem', 'kondusif', 'sehingga', 'bisa', 'lebih', 'berkontribusi', 'indonesia', 'maju', 'ekosistem', 'demokrasi', 'ideologi', 'pancasila', 'kokoh', 'bhinneka', 'tunggal', 'ika', 'semangat', 'gotong', 'royong', 'ditopang', 'dengan', 'tata', 'kelola', 'pemerintahan', 'baik', 'upaya', 'membebaskan', 'indonesia', 'dari', 'jeratan', 'korupsi', 'mengkhianati', 'kepercayaan', 'rakyat', 'menggerogoti', 'anggaran', 'negara', 'merusak', 'sendi-sendi', 'perekonomian', 'bangsa', 'terus', 'dilakukan', 'korupsi', 'adalah', 'kejahatan', 'luar', 'biasa', 'dilawan', 'dengan', 'cara-cara', 'luar', 'biasa', 'pemerintah', 'akan', 'terus', 'mendukung', 'upaya', 'kpk', 'memberantas', 'korupsi', 'pemerintah', 'juga', 'memberikan', 'prioritas', 'tinggi', 'pada', 'upaya', 'pencegahan', 'sebagaimana', 'halnya', 'dengan', 'upaya', 'penindakan', 'pemerintah', 'telah', 'mengeluarkan', 'strategi', 'nasional', 'pencegahan', 'korupsi', 'melalui', 'peraturan', 'presiden', 'nomor', '54', 'tahun', '2018', 'sebagai', 'arah', 'kebijakan', 'nasional', 'memuat', 'fokus', 'sasaran', 'pencegahan', 'korupsi', 'selain', 'pemerintah', 'juga', 'meneruskan', 'inisiatif', 'saber', 'pungli', 'satuan', 'tugas', 'sapu', 'bersih', 'pungutan', 'liar', 'sampai', 'semester', 'i', 'tahun', '2018', 'telah', 'melaksanakan', '2911', 'kegiatan', 'operasi', 'tangkap', 'tangan', 'juga', 'memberikan', 'perhatian', 'kuat', 'pada', 'upaya', 'penghormatan', 'perlindungan', 'pemenuhan', 'penegakan', 'hak', 'asasi', 'manusia', 'menjadi', 'semangat', 'pemerintah', 'dalam', 'mengeluarkan', 'peraturan', 'presiden', 'nomor', '33', 'tahun', '2018', 'tentang', 'perubahan', 'atas', 'peraturan', 'presiden', 'nomor', '75', 'tahun', '2015', 'tentang', 'rencana', 'aksi', 'nasional', 'hak', 'asasi', 'manusia', '(', 'ranham', ')', 'tahun', '2015-2019', 'pemerintah', 'berupaya', 'mempercepat', 'penyelesaian', 'kasus-kasus', 'ham', 'masa', 'lalu', 'serta', 'meningkatkan', 'perlindungan', ' ...

# %%
stop_words = set(stopwords.words('indonesian'))
word_tokens_no_stopwords = [w for w in word_tokens if not w in stop_words]
print(word_tokens_no_stopwords)
# Out:
# ['memperkuat', 'fondasi', 'mengumpulkan', 'energi', 'lompatan', 'kemajuan', 'berani', 'terobosan', 'melompat', 'berani', 'kebijakan', 'hasilnya', 'nikmati', 'langkah', 'cepat', 'terjebak', 'pragmatisme', 'jangka', 'pendek', 'jalan', 'melambat', 'terjebak', 'status', 'negara', 'berpenghasilan', 'menengah', 'terkena', 'middle', 'income', 'trap', 'berhasil', 'negara', 'maju', 'indonesia', 'maju', 'lakukan', 'kemarin', 'memecahkan', 'satu-dua', 'lompatan', 'kemajuan', 'indonesia', 'masalah-masalah', 'keberhasilan', 'timnas', 'sepakbola', 'indonesia', 'u-16', 'menjuarai', 'turnamen', 'asean', 'football', 'federation', '11', 'agustus', '2018', 'salah', 'contohnya', 'tim', 'berusia', '16', 'sepakbola', 'indonesia', 'indonesia', 'benih-benih', 'harapan', 'kejayaan', 'bangsa', 'indonesia', 'bersemai', 'putra-putri', 'indonesia', 'mengibarkan', 'bendera', 'merah', 'putih', 'pentas', 'dunia', 'prestasi', 'gemilang', 'membanggakan', 'diraih', 'putraputri', 'indonesia', 'kompetisi', 'tingkat', 'dunia', 'kompetisi', 'big', 'sains', 'teknologi', 'lomba', 'hafal', 'al-quran', 'festival', 'seni', 'budaya', 'kejuaraan', 'olah', 'raga', 'kompetisi', 'berhasil', 'menggaet', 'posisi', 'terhormat', 'prestasi', 'diraih', 'anak-anak', 'bangsa', 'didukung', 'ekosistem', 'kondusif', 'berkontribusi', 'indonesia', 'maju', 'ekosistem', 'demokrasi', 'ideologi', 'pancasila', 'kokoh', 'bhinneka', 'tunggal', 'ika', 'semangat', 'gotong', 'royong', 'ditopang', 'tata', 'kelola', 'pemerintahan', 'upaya', 'membebaskan', 'indonesia', 'jeratan', 'korupsi', 'mengkhianati', 'kepercayaan', 'rakyat', 'menggerogoti', 'anggaran', 'negara', 'merusak', 'sendi-sendi', 'perekonomian', 'bangsa', 'korupsi', 'kejahatan', 'dilawan', 'cara-cara', 'pemerintah', 'mendukung', 'upaya', 'kpk', 'memberantas', 'korupsi', 'pemerintah', 'prioritas', 'upaya', 'pencegahan', 'halnya', 'upaya', 'penindakan', 'pemerintah', 'mengeluarkan', 'strategi', 'nasional', 'pencegahan', 'korupsi', 'peraturan', 'presiden', 'nomor', '54', '2018', 'arah', 'kebijakan', 'nasional', 'memuat', 'fokus', 'sasaran', 'pencegahan', 'korupsi', 'pemerintah', 'meneruskan', 'inisiatif', 'saber', 'pungli', 'satuan', 'tugas', 'sapu', 'bersih', 'pungutan', 'liar', 'semester', 'i', '2018', 'melaksanakan', '2911', 'kegiatan', 'operasi', 'tangkap', 'tangan', 'perhatian', 'kuat', 'upaya', 'penghormatan', 'perlindungan', 'pemenuhan', 'penegakan', 'hak', 'asasi', 'manusia', 'semangat', 'pemerintah', 'mengeluarkan', 'peraturan', 'presiden', 'nomor', '33', '2018', 'perubahan', 'peraturan', 'presiden', 'nomor', '75', '2015', 'rencana', 'aksi', 'nasional', 'hak', 'asasi', 'manusia', '(', 'ranham', ')', '2015-2019', 'pemerintah', 'berupaya', 'mempercepat', 'penyelesaian', 'kasus-kasus', 'ham', 'meningkatkan', 'perlindungan', 'ham', 'kejadian', 'terulang', 'lompatan', 'kemajuan', 'membutuhkan', 'keberanian', 'memiliki', 'ketegasan', 'mengambil', 'keputusan', 'terbaik', 'kepentingan', 'rakyat', 'indonesia', 'ketegasan', 'melindungi', 'hutan', 'lahan', 'upaya', 'membuahkan', 'hasil', 'area', 'kebakaran', 'hutan', 'lahan', 'menurun', 'signifikan', 'dibandingkan', 'tahun-tahun', 'ketegasan', 'maksimal', 'dukungan', 'partisipasi', 'masyarakat', 'terima', 'kasih', 'penghargaan', 'aparat', 'tni', 'polri', 'pemerintah', 'daerah', 'warga', 'masyarakat', 'penuh', 'dedikasi', 'mencegah', 'melawan', 'ancaman', 'kebakaran', 'hutan', 'ketegasan', 'dibutuhkan', 'pemberantasan', 'narkoba', 'merusak', 'bangsa', 'upaya', 'membutuhkan', 'kerja', 'menyelamatkan', 'nyawa', 'belasan', 'ribu', 'putra-putri', 'tahunnya', 'korban', 'kejahatan', 'narkoba', 'ketegasan', 'menjaga', 'kekayaan', 'alam', 'berdaulat', 'sumber', 'daya', 'alam', 'kedaulatan', 'maritim', 'laut', 'teluk', 'samudra', 'jaga', 'main-main', 'aksi', 'pencurian', 'ikan', 'perairan', 's', 'dekade', 'tangan', 'blok', 'migas', 'mahakam', 'blok', 'migas', 'sanga-sanga', 'blok', 'migas', 'rokan', 'mayoritas', 'saham', 'freeport', 'pangkuan', 'pertiwi', 'sebesar-besarnya', 'kemakmuran', 'rakyat', 'm ...

# %%
freq_kata_1 = nltk.FreqDist(word_tokens)
freq_kata_2 = nltk.FreqDist(word_tokens_no_stopwords)
print(freq_kata_1.most_common(20))
print()
print(freq_kata_2.most_common(20))
# Out:
# [('indonesia', 12), ('depan', 8), ('dalam', 8), ('dengan', 8), ('upaya', 8), ('pemerintah', 8), ('ke', 7), ('di', 7), ('masa', 7), ('tahun', 7), ('menjadi', 6), ('juga', 6), ('tni', 6), ('polri', 6), ('pada', 5), ('negara', 5), ('bangsa', 5), ('korupsi', 5), ('terus', 5), ('ketegasan', 5)]
#
# [('indonesia', 12), ('upaya', 8), ('pemerintah', 8), ('tni', 6), ('polri', 6), ('negara', 5), ('bangsa', 5), ('korupsi', 5), ('ketegasan', 5), ('2018', 4), ('lompatan', 3), ('kemajuan', 3), ('maju', 3), ('kompetisi', 3), ('rakyat', 3), ('pencegahan', 3), ('nasional', 3), ('peraturan', 3), ('presiden', 3), ('nomor', 3)]

# %%
import matplotlib.pyplot as plt

# %%
freq_kata_1.plot(20)
freq_kata_2.plot(20)
plt.show()

# %%
#Import datavis libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Figures inline and set visualization style
# %matplotlib inline
sns.set()

# Create freq dist and plot
freqdist1 = nltk.FreqDist(word_tokens_no_stopwords)
freqdist1.plot(25)
plt.show()
