# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bertopic in /usr/local/lib/python3.8/dist-packages (0.13.0)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.8/dist-packages (from bertopic) (5.5.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.8/dist-packages (from bertopic) (1.21.6)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from bertopic) (0.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.8/dist-packages (from bertopic) (1.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.8/dist-packages (from bertopic) (1.3.5)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.8/dist-packages (from bertopic) (0.8.29)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.8/dist-packages (from bertopic) (4.64.1)
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.8/dist-packages (from bertopic) (5.4.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.32)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from hdbscan>=0.8.29->bertopic) (1.7.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->bertopic) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly>=4.7.0->bertopic) (8.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.7)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.97)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.13.0+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.14.0+cu116)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.25.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.11.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.8/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.4.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.25.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (5.2.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.49->umap-learn>=0.5.0->bertopic) (3.11.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.10)

# %%
#import packages

import pandas as pd 
import numpy as np
from bertopic import BERTopic

# %%
#load data 
import pandas as pd 
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('./drive/MyDrive/Colab Notebooks/UAS_NLP/tripadvisor_hotel_reviews.csv')
 
# select only 6000  
df = df[0:6000]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head(10)
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
# 5  love monaco staff husband stayed hotel crazy w...       5
# 6  cozy stay rainy city, husband spent 7 nights m...       5
# 7  excellent staff, housekeeping quality hotel ch...       4
# 8  hotel stayed hotel monaco cruise, rooms genero...       5
# 9  excellent stayed hotel monaco past w/e delight...       5

# %%
# create model 
 
model = BERTopic(verbose=True)
 
#convert to list 
docs = df.Review.to_list()
 
topics, probabilities = model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/188 [00:00<?, ?it/s]
# 2023-01-07 10:25:49,128 - BERTopic - Transformed documents to Embeddings
# 2023-01-07 10:26:07,662 - BERTopic - Reduced dimensionality
# 2023-01-07 10:26:07,919 - BERTopic - Clustered reduced embeddings

# %%
model.get_topic_freq().head(11)
# Out:
#     Topic  Count
# 0      -1   1904
# 1       0    340
# 2       1    334
# 3       2    284
# 4       3    280
# 5       4    261
# 6       5    245
# 7       6    238
# 8       7    219
# 9       8    136
# 10      9    135

# %%
model.get_topic(0)
# Out:
# [('francisco', 0.032705337173092826),
#  ('san', 0.02473508042984737),
#  ('chancellor', 0.020964279247644053),
#  ('union', 0.019798322753597098),
#  ('sf', 0.017304741417690943),
#  ('location', 0.017165868077392343),
#  ('inn', 0.017085010992619575),
#  ('cable', 0.015714955969546855),
#  ('great', 0.015034996514812682),
#  ('hotel', 0.01501086451118865)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="28cfdfe3-86e1-4937-b801-224afd8bf765" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28cfdfe3-86e1-4937-b801-224afd8bf765")) {                    Plotly.newPlot(                        "28cfdfe3-86e1-4937-b801-224afd8bf765",                        [{"customdata":[[0,"francisco | san | chancellor | union | sf",340],[1,"seattle | downtown | hotel | room | pike",334],[2,"juan | san | old | puerto | rico",284],[3,"beach | resort | not | pool | food",280],[4,"room | not | hotel | no | told",261],[5,"florence | hotel | casci | duomo | breakfast",245],[6,"location | hotel | great | staff | stay",238],[7,"paris | hotel | metro | staff | location",219],[8,"london | bridge | hotel | chesterfield | tube",136],[9,"orleans | quarter | new | french | charles",135],[10,"waikiki | parc | kahala | beach | view",116],[11,"berlin | hotel | location | breakfast | station",92],[12,"amsterdam | canal | hotel | dam | breakfast",73],[13,"room | bed | small | bathroom | great",72],[14,"barcelona | hotel | catalunya | majestic | ramblas",71],[15,"beach | great | venice | hotel | pool",67],[16,"bavaro | princess | beach | resort | not",66],[17,"casablanca | rick | york | cheese | wine",61],[18,"hotel | room | not | price | night",55],[19,"hotel | room | breakfast | not | desk",52],[20,"melia | caribe | tropical | resort | not",48],[21,"husband | lovely | wonderful | room | hotel",44],[22,"noise | noisy | room | hotel | rooms",43],[23,"boston | lenox | quincy | location | hotel",43],[24,"sofitel | york | new | nyc | hotel",43],[25,"mexico | city | zocalo | polanco | reforma",41],[26,"club | kids | punta | cana | med",39],[27,"madrid | palace | westin | prado | location",36],[28,"ritz | carlton | ritzcarlton | not | hotel",34],[29,"frankfurt | airport | train | hotel | station",33],[30,"bambu | riu | holiday | entertainment | beach",28],[31,"iberostar | punta | cana | bavaro | resort",27],[32,"airport | shuttle | flight | seatac | noise",26],[33,"cana | punta | beach | food | best",25],[34,"rex | francisco | san | hotel | union",24],[35,"milano | juan | san | old | hotel",23],[36,"conquistador | el | resort | island | las",20],[37,"riu | taino | beach | resort | palace",20],[38,"dallas | downtown | lawrence | adolphus | magnolia",19],[39,"palace | york | new | cathedral | suite",19],[40,"natura | park | resort | not | people",19],[41,"paradisus | resort | beach | time | not",18],[42,"hilton | square | times | view | nyc",18],[43,"gem | staff | clean | parkcity | second",18],[44,"fairmont | copley | boston | plaza | gold",17],[45,"toronto | eaton | centre | marriott | hotel",17],[46,"cambridge | suites | toronto | eaton | suite",15],[47,"copamarina | copa | guanica | puerto | island",15],[48,"resort | beach | food | dominican | did",14],[49,"hix | vieques | island | house | nature",14],[50,"nyc | york | new | hilton | square",14],[51,"friendly | staff | central | points1 | quiet",14],[52,"omni | berkshire | madison | weekend | room",13],[53,"room | hotel | suite | spice | kiosk",13],[54,"beijing | china | wall | inn | marriott",12],[55,"empire | state | central | building | location",11],[56,"bambu | riu | cana | punta | beach",11],[57,"ramblas | rivoli | catalunya | location | plaza",11]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>Words: %{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[340,334,284,280,261,245,238,219,136,135,116,92,73,72,71,67,66,61,55,52,48,44,43,43,43,41,39,36,34,33,28,27,26,25,24,23,20,20,19,19,19,18,18,18,17,17,15,15,14,14,14,14,13,13,12,11,11,11],"sizemode":"area","sizeref":0.2125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v", ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e929f3de-6cf2-4c05-9a29-4aee10ade6af" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e929f3de-6cf2-4c05-9a29-4aee10ade6af")) {                    Plotly.newPlot(                        "e929f3de-6cf2-4c05-9a29-4aee10ade6af",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.017304741417690943,0.019798322753597098,0.020964279247644053,0.02473508042984737,0.032705337173092826],"y":["sf  ","union  ","chancellor  ","san  ","francisco  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.013970594455990628,0.014046973942500679,0.015868050152554946,0.01942926892348839,0.04417843879169849],"y":["pike  ","room  ","hotel  ","downtown  ","seattle  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.013932536640267426,0.01566821125696464,0.015849699426144708,0.029530736286637157,0.03386519461343078],"y":["rico  ","puerto  ","old  ","san  ","juan  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.012329230853514573,0.012804192931725765,0.01297194747160676,0.015215027766853741,0.017883169643272318],"y":["food  ","pool  ","not  ","resort  ","beach  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01318473391514445,0.013257346507425615,0.013271889107584227,0.017400932617900225,0.02004161397781366],"y":["told  ","no  ","hotel  ","not  ","room  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.01543999654035058,0.015473273357354957,0.0182372887371688,0.021559229772301715,0.05511953891723566],"y":["breakfast  ","duomo  ","casci  ","hotel  ","florence  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.018139000608292877,0.02182469190291438,0.02833372644203927,0.029670326044872714,0.03178912766709677],"y":["stay  ","staff  ","great  ","hotel  ","location  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.013525347705638418,0.0144302558960739,0.020305485005636073,0.020936171234717145,0.05672619387122857],"y":["location  ","staff  ","metro  ","hotel  ","paris  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556, ...

# %%
model = BERTopic(nr_topics=20)

# %%
topics, probabilities = model.fit_transform(docs)
# Out:
# 2023-01-07 10:33:57,114 - BERTopic - Transformed documents to Embeddings
# 2023-01-07 10:34:16,514 - BERTopic - Reduced dimensionality
# 2023-01-07 10:34:16,772 - BERTopic - Clustered reduced embeddings
# 2023-01-07 10:34:21,275 - BERTopic - Reduced number of topics from 58 to 21

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5699dd4d-93fb-4baf-84ec-3cc4997f35f3" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5699dd4d-93fb-4baf-84ec-3cc4997f35f3")) {                    Plotly.newPlot(                        "5699dd4d-93fb-4baf-84ec-3cc4997f35f3",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01937611339183911,0.019589632979022522,0.0241572824226123,0.025188486617744008,0.02697745072603688],"y":["nt  ","food  ","not  ","resort  ","beach  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02648533773044273,0.027598126923619112,0.031859039257178215,0.03571627096017438,0.04336400746171892],"y":["great  ","location  ","hotel  ","san  ","francisco  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02032853362675075,0.0221233756374028,0.026165366330106337,0.04118536053054258,0.045726961038666046],"y":["puerto  ","old  ","hotel  ","san  ","juan  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.021254062634127623,0.027240374932417412,0.02735211252616322,0.03165698263940359,0.06452509917843029],"y":["stay  ","room  ","downtown  ","hotel  ","seattle  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.028352089706016558,0.03227071997081052,0.0416095607003624,0.043363061042282124,0.0507027543535081],"y":["good  ","staff  ","great  ","location  ","hotel  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.02282177508308943,0.023232755938587448,0.023991402035095213,0.04349890708068608,0.06979882650381947],"y":["location  ","room  ","breakfast  ","hotel  ","florence  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.021874562585773406,0.02200484935040398,0.028543165222006266,0.034094336648018565,0.038387367388867374],"y":["no  ","nt  ","hotel  ","not  ","room  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.024167807103446126,0.025393321555298807,0.02598123769996959,0.04230591086587646,0.07231894715155095],"y":["staff  ","metro  ","room  ","hotel  ","paris  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[ ...
